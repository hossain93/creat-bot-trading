# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
# !pip install pytse-client
# !pip install pytse
url = "http://www.tsetmc.com/tsev2/data/MarketWatchPlus.aspx"
payload={}
files={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload, files=files) 
main_text = response.text
Mkt_df = pd.DataFrame((main_text.split('@')[2]).split(';'))
Mkt_df = Mkt_df[0].str.split(",",expand=True)
Mkt_df
# Out:
# 'PK\x03\x04\x14\x00\x00\x00\x08\x00���T8�f}�\x00\x00\x00h\x01\x00\x00\x0f\x00\x1c\x00xl/workbook.xml �\x18\x00(�\x14\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00���N�0\x10�_ź�:��DQ�.,�\x0c�nrn�ƾ�vi�\x00\x16�\x03�\nV\x06^�\x15\x0f�+���"&���է�w�o����-�C�\x14�\x02�\'\t04\x15�ʬ\x0b�zy�²��lGv�"ڰxo\\�\x17�x�e���A-܄:4q\'�j�ck��u\x16E�\x1aD�[>M�\x05�B\x19\x18�\x06�[�;�[|\x180^���~�8U�\x08�\x05���c�\x1f\x1eXx\x0eO��1��\x18/�ƻ�:\x12\x01���ō�\\���,M�E:��\x19\x1cQ�\x7fPHJU�\x15U[��\x7f�Xl��os��\x1c\x1c}�X�\'��\x0bPK\x03\x04\n\x00\x00\x00\x00\x00���TG�&\x1d(\x01\x00\x00(\x01\x00\x00\x0b\x00\x1c\x00_rels/.rels �\x18\x00(�\x14\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ufeff<?xml version="1.0" encoding="utf-8"?><Relationships xmlns="http://schemas.openxmlformats.org/package/2006/relationships"><Relationship Type="http://schemas.openxmlformats.org/officeDocument/2006/relationships/officeDocument" Target="/xl/workbook.xml
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
# !pip install pytse-client
# !pip install pytse
url = "http://www.tsetmc.com/Loader.aspx?ParTree=15"
payload={}
files={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload, files=files)   
soup=BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    .:TSETMC:. :: شرکت مدیریت فناوری بورس تهران
#   </title>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-63076930-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];  function gtag(){dataLayer.push(arguments);}  gtag('js', new Date());  gtag('config', 'UA-63076930-1');
#   </script>
#   <script>
# ...

# %%
stop=soup.find('div',attrs={'class':'box1 red tbl z4_4'})
stop=stop
#stop=BeautifulSoup(stop,'html.parser')
# stop=stop.find_all('a')
# for i in stop:
#     print(i.text)
th=stop.find_all('th')
tr=stop.find_all('td')
title=[]
data=[]
for i in td:
    #print(i.text)
    title.append(i.text)
for i in tr:
    #print(i.text)
    data.append(i.text)
#data.pop(0)
data
# Out:
# ['\nس.سهام عدالت استان مازندران (وسمازن)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nبانك سينا (وسينا)\n',
#  '\r\n                                    بررسی وضعیت شفافیت اطلاعاتی ناشر\n',
#  '\nشركت س استان هرمزگان (وسهرمز)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهعدم ارائه گزارش فعالیت ماهانه بهمن ماهعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان فارس (وسفارس)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهبررسی وضعیت شفافیت اطلاعاتی ناشرعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان خراسان شمالي (وسخراش)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهبررسی وضعیت شفافیت اطلاعاتی ناشرعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان كردستان (وسكرد)\n',
# ...

# %%
data
# Out:
# ['\nس.سهام عدالت استان مازندران (وسمازن)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nبانك سينا (وسينا)\n',
#  '\r\n                                    بررسی وضعیت شفافیت اطلاعاتی ناشر\n',
#  '\nشركت س استان هرمزگان (وسهرمز)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهعدم ارائه گزارش فعالیت ماهانه بهمن ماهعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان فارس (وسفارس)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهبررسی وضعیت شفافیت اطلاعاتی ناشرعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان خراسان شمالي (وسخراش)\n',
#  '\r\n                                    عدم ارائه گزارش تفسیری مدیریت 12 ماهه حسابرسی شدهبررسی وضعیت شفافیت اطلاعاتی ناشرعدم ارائه صورت های مالی 12 ماهه حسابرسی شده\n',
#  '\nشركت س استان كردستان (وسكرد)\n',
# ...

# %%
df=pd.DataFrame(data)
taligh=pd.DataFrame(columns=title)
i=0
while i< len(data):
    try:
        taligh.at[i,'نماد']=df.at[i*2,0]
        taligh.at[i,'علت']=df.at[i*2+1,0]
        i+=2
    except Exception as error:
        break
taligh.to_pickle("taligh.pkl")
# Out:
#                                          نماد  \
# 0    \nس.سهام عدالت استان مازندران (وسمازن)\n
# 2           \nشركت س استان هرمزگان (وسهرمز)\n
# 4      \nشركت س استان خراسان شمالي (وسخراش)\n
# 6   \nشركت س استان آذربايجان غربي (وساغربي)\n
# 8    \nس.سهام عدالت استان كرمانشاه (وسكرشا)\n
# 10            \nشركت س استان همدان (وسهمدا)\n
# 12           \nشركت س استان زنجان (وسزنجان)\n
# 14               \nشركت س استان يزد (وسيزد)\n
# 16            \nشركت س استان مركزي (وسمركز)\n
# 18            \nشركت س استان ايلام (وسيلام)\n
# 20          \nشركت س استان اردبيل (وساربيل)\n
# 22          \nشركت س استان گلستان (وسگلستا)\n
# 24  \nشركت س استان آذربايجان شرقي (وساشرقي)\n
# 26           \nشركت س استان بوشهر (وسبوشهر)\n
# 28              \nكنتورسازي‌ايران‌ (آكنتور)\n
#
#                                                   علت
# 0   \r\n                                    عدم ار...
# 2   \r\n                                    عدم ار...
# 4   \r\n                                    عدم ار...
# ...

# %%
taligh_old = pd.read_pickle("taligh.pkl")
